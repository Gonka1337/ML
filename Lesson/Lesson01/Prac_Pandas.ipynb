# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('../../Desktop/titanic_train.csv',
                  index_col ='PassengerId')

# %%
data.head(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data[(data['Embarked'] == 'C') & (data['Fare'] > 200)].head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 119                 0       1
# 259                 1       1
# 300                 1       1
# 312                 1       1
# 378                 0       1
#
#                                                         Name     Sex   Age  \
# PassengerId
# 119                                 Baxter, Mr. Quigg Edmond    male  24.0
# 259                                         Ward, Miss. Anna  female  35.0
# 300          Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0
# 312                               Ryerson, Miss. Emily Borie  female  18.0
# 378                                Widener, Mr. Harry Elkins    male  27.0
#
#              SibSp  Parch    Ticket      Fare            Cabin Embarked
# PassengerId
# 119              0      1  PC 17558  247.5208          B58 B60        C
# 259              0      0  PC 17755  512.3292              NaN        C
# ...

# %%
data[(data['Embarked'] == 'C') & 
     (data['Fare'] > 200)].sort_values(by='Fare',
                                       ascending=False).head()
# Out:
#              Survived  Pclass                                   Name     Sex  \
# PassengerId
# 259                 1       1                       Ward, Miss. Anna  female
# 680                 1       1     Cardeza, Mr. Thomas Drake Martinez    male
# 738                 1       1                 Lesurer, Mr. Gustave J    male
# 312                 1       1             Ryerson, Miss. Emily Borie  female
# 743                 1       1  Ryerson, Miss. Susan Parker "Suzette"  female
#
#               Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# PassengerId
# 259          35.0      0      0  PC 17755  512.3292              NaN        C
# 680          36.0      0      1  PC 17755  512.3292      B51 B53 B55        C
# 738          35.0      0      0  PC 17755  512.3292             B101        C
# 312          18.0      2      2  PC 17608  262.3750  B57 B59 B63 B66        C
# 743          21.0      2      2  PC 17608  262.3750  B57 B59 B63 B66        C

# %%
def age_category(age):
    '''
    < 30 -> 1
    > 60 ->2
    '''
    if age < 30:
        return '< 30'
    elif age > 60:
        return '> 60'
    else:
        return 'other'

# %%
age_categories = [age_category(age) for age in data.Age]

# %%
data['Age_category'] = age_categories

# %%
data['Age_category'] = data['Age'].apply(age_category)

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# ...

# %%
data['Sex'].head()
# Out:
# PassengerId
# 1      male
# 2    female
# 3    female
# 4    female
# 5      male
# Name: Sex, dtype: object

# %%
data.iloc[:,3].head()
# Out:
# PassengerId
# 1      male
# 2    female
# 3    female
# 4    female
# 5      male
# Name: Sex, dtype: object

# %%
d = {'female': 1 , 'male': 0}

# %%
data['Sex'].map(d).head()
# Out:
# PassengerId
# 1    0
# 2    1
# 3    1
# 4    1
# 5    0
# Name: Sex, dtype: int64

# %%
data.sort_values(by='Sex', 
                 ascending = False).head()
# Out:
#              Survived  Pclass                               Name   Sex   Age  \
# PassengerId
# 1                   0       3            Braund, Mr. Owen Harris  male  22.0
# 496                 0       3              Yousseff, Mr. Gerious  male   NaN
# 537                 0       1  Butt, Major. Archibald Willingham  male  45.0
# 539                 0       3           Risien, Mr. Samuel Beard  male   NaN
# 544                 1       2                  Beane, Mr. Edward  male  32.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked Age_category
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S         < 30
# 496              0      0       2627  14.4583   NaN        C        other
# 537              0      0     113050  26.5500   B38        S        other
# 539              0      0     364498  14.5000   NaN        S        other
# 544              1      0       2908  26.0000   NaN        S        other

# %%
data['Sex'].describe()
# Out:
# count      891
# unique       2
# top       male
# freq       577
# Name: Sex, dtype: object

# %%
data[(data['Sex'] == 'female')].head
# Out:
# <bound method NDFrame.head of              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 9                   1       3
# 10                  1       2
# ...               ...     ...
# 881                 1       2
# 883                 0       3
# 886                 0       3
# 888                 1       1
# 889                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# ...

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'Age_category'],
#       dtype='object')

# %% [markdown]
# ### Сколько мужчин / женщин находилось на борту?
#
# * 577 мужчин и 314 женщин

# %%
#Самое простое решение для типов object и bool тое есть не цифровых.
data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# ### Выведите распределение переменной Pclass (социально-экономический статус) и это же распределение, только для мужчин / женщин по отдельности. Сколько было мужчин 2-го класса?
# * 108

# %%
pd.crosstab(data['Sex'], data['Pclass'])
# Out:
# Pclass    1    2    3
# Sex
# female   94   76  144
# male    122  108  347

# %% [markdown]
# ### Каковы медиана и стандартное отклонение платежей (Fare)? Округлите до 2 десятичных знаков.
# * Медиана – 14.45, стандартное отклонение – 49.69

# %%
pd.set_option('precision', 2)

# %%
data['Fare'].describe()
# Out:
# count    891.00
# mean      32.20
# std       49.69
# min        0.00
# 25%        7.91
# 50%       14.45
# 75%       31.00
# max      512.33
# Name: Fare, dtype: float64

# %% [markdown]
# ### Правда ли, что люди моложе 30 лет выживали чаще, чем люди старше 60 лет? Каковы доли выживших в обеих группах?

# %%
pd.set_option('precision', 3)

# %%
data.pivot_table(['Survived'], ['Age_category'], aggfunc='mean').head()
# Out:
#               Survived
# Age_category
# < 30             0.406
# > 60             0.227
# other            0.373

# %% [markdown]
# * 40.6% среди молодых и 22.7% среди старых

# %% [markdown]
# ### Правда ли, что женщины выживали чаще мужчин? Каковы доли выживших в обеих группах?

# %%
data.pivot_table(['Survived'], ['Sex'], aggfunc ='mean').head()
# Out:
#         Survived
# Sex
# female     0.742
# male       0.189

# %% [markdown]
# * 18.9% среди мужчин и 74.2% среди женщин

# %%
data['Name'].describe()
# Out:
# count                        891
# unique                       891
# top       Alexander, Mr. William
# freq                           1
# Name: Name, dtype: object

# %%
pd.plotting.scatter_matrix(data[['Fare', 'Age', 'Survived' ]],
                          figsize=(15,15), diagonal='kde')
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-35e8fdc6e00d> in <module>
#       1 pd.plotting.scatter_matrix(data[['Fare', 'Age', 'Survived' ]],
#       2                           figsize=(15,15), diagonal='kde')
# ----> 3 plt.show
#
# NameError: name 'plt' is not defined

# %%
data.boxplot(column='Survived', by=['Fare', 'Age'],
            figsize=(10,10))
plt.show

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (8, 6)

# %%
data.boxplot(column='Survived',   by=['Age'], 
           figsize=(10,10))
plt.show()

# %%
pd.crosstab(data['Fare'] & data['Age'] , 
            data['Survived'])

# %%
pd.crosstab(data['Fare'], data['Age'])

# %% [markdown]
# ### Сравните графически распределение стоимости билетов и возраста у спасенных и у погибших. Средний возраст погибших выше, верно?
# * Да

# %%
sns.boxplot(x='Survived', y='Age', data=data);

# %%
sns.boxplot(x='Survived', y='Fare', data=data);

# %%
data.boxplot(column='Age',  by=['Survived'], 
           figsize=(10,10))
plt.show()

# %% [markdown]
# ## Как отличается средний возраст мужчин / женщин в зависимости от класса обслуживания? Выберите верные утверждения:
# * В среднем мужчины 1-го класса старше 40 лет
# * Мужчины всех классов в среднем старше женщин того же класса
# * В среднем люди в 1 классе старше, чем во 2-ом, а те старше представителей 3-го класса

# %%
sns.boxplot(x='Pclass', y='Age', data=data);

# %%
data[(data['Pclass'] == 1) & (data['Sex'] == 'male')]['Age'].mean()

# %%
data[(data['Pclass'] == 2) & (data['Sex'] == 'male')]['Age'].mean()

# %%
data[(data['Pclass'] == 3) & (data['Sex'] == 'male')]['Age'].mean()

# %%
data[(data['Pclass'] == 1) & (data['Sex'] == 'female')]['Age'].mean()

# %%
data[(data['Pclass'] == 2) & (data['Sex'] == 'female')]['Age'].mean()

# %%
data[(data['Pclass'] == 3) & (data['Sex'] == 'female')]['Age'].mean()

# %% [markdown]
#  ## Найдите самое популярное имя среди пассажиров Титаника мужского пола?
#  * William

# %%
data['Name'].value_counts().head()
# Out:
# Alexander, Mr. William              1
# Mullens, Miss. Katherine "Katie"    1
# Van Impe, Mr. Jean Baptiste         1
# Eklund, Mr. Hans Linus              1
# Lines, Miss. Mary Conover           1
# Name: Name, dtype: int64

# %%
all_words = np.concatenate(data['Name'].apply(lambda s:
                                        s.strip().split()).values)

# %%
data['Name'].apply(lambda s: s.strip().split()).values
# Out:
# array([list(['Braund,', 'Mr.', 'Owen', 'Harris']),
#        list(['Cumings,', 'Mrs.', 'John', 'Bradley', '(Florence', 'Briggs', 'Thayer)']),
#        list(['Heikkinen,', 'Miss.', 'Laina']),
#        list(['Futrelle,', 'Mrs.', 'Jacques', 'Heath', '(Lily', 'May', 'Peel)']),
#        list(['Allen,', 'Mr.', 'William', 'Henry']),
#        list(['Moran,', 'Mr.', 'James']),
#        list(['McCarthy,', 'Mr.', 'Timothy', 'J']),
#        list(['Palsson,', 'Master.', 'Gosta', 'Leonard']),
#        list(['Johnson,', 'Mrs.', 'Oscar', 'W', '(Elisabeth', 'Vilhelmina', 'Berg)']),
#        list(['Nasser,', 'Mrs.', 'Nicholas', '(Adele', 'Achem)']),
#        list(['Sandstrom,', 'Miss.', 'Marguerite', 'Rut']),
#        list(['Bonnell,', 'Miss.', 'Elizabeth']),
#        list(['Saundercock,', 'Mr.', 'William', 'Henry']),
#        list(['Andersson,', 'Mr.', 'Anders', 'Johan']),
#        list(['Vestrom,', 'Miss.', 'Hulda', 'Amanda', 'Adolfina']),
# ...

# %%
len(all_words)
# Out:
# 3624

# %%
word_series = pd.Series(list(all_words))

# %%
word_series.value_counts()
# Out:
# Mr.            517
# Miss.          182
# Mrs.           125
# William         62
# John            44
#               ...
# Odahl,           1
# Thuillard)       1
# Rizk)            1
# Connaghton,      1
# Pain,            1
# Length: 1673, dtype: int64

# %%
word_series.unique()
# Out:
# array(['Braund,', 'Mr.', 'Owen', ..., 'Behr,', 'Howell', 'Dooley,'],
#       dtype=object)

# %%
# Out:
# Object `uni` not found.
